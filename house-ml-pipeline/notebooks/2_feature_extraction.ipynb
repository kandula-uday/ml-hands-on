# %% [markdown]
# # 🏠 Toronto Housing Data - Feature Extraction
#
# In this notebook, we:
# - Load raw CSV data from multiple area folders
# - Clean price field
# - Extract features: beds, baths, category (Townhouse/Condo/House)
# - Extract city/area from address

# %%
import pandas as pd
import os
import re
from pathlib import Path

# Set path to combined CSV (after merging area-wise files)
csv_path = Path('../data/toronto_combined.csv')
df = pd.read_csv(csv_path)
df.head()
# Out:
#                                       address        price  \
# 0         218 Golden Trl, Vaughan, ON L6A 5A1  C$1,199,000
# 1          24 Sicilia St, Vaughan, ON L4H 1G3  C$1,399,999
# 2  81 Mahogany Forest Dr, Vaughan, ON L6A 0T1  C$1,258,800
# 3      99 Abner Miles Dr, Vaughan, ON L6A 4X4  C$2,299,000
# 4       26 Bruce St #E17, Vaughan, ON L4L 0H4    C$649,999
#
#                          details
# 0  3 bds3 ba- Townhouse for sale
# 1      4 bds4 ba- House for sale
# 2      4 bds4 ba- House for sale
# 3      5 bds6 ba- House for sale
# 4      2 bds2 ba- Condo for sale

# %% [markdown]
# ## 💰 Clean Price Column

# %%
df['price'] = (
    df['price']
    .str.replace(r'[^\d.]', '', regex=True)
    .pipe(pd.to_numeric, errors='coerce')
)
df.head()
# Out:
#                                       address      price  \
# 0         218 Golden Trl, Vaughan, ON L6A 5A1  1199000.0
# 1          24 Sicilia St, Vaughan, ON L4H 1G3  1399999.0
# 2  81 Mahogany Forest Dr, Vaughan, ON L6A 0T1  1258800.0
# 3      99 Abner Miles Dr, Vaughan, ON L6A 4X4  2299000.0
# 4       26 Bruce St #E17, Vaughan, ON L4L 0H4   649999.0
#
#                          details
# 0  3 bds3 ba- Townhouse for sale
# 1      4 bds4 ba- House for sale
# 2      4 bds4 ba- House for sale
# 3      5 bds6 ba- House for sale
# 4      2 bds2 ba- Condo for sale

# %%
invalid_price_rows = df[~pd.to_numeric(df['price'], errors='coerce').notnull()]

print(invalid_price_rows)
# Out:
#                                    address  price  \
# 3534  Coming Soon Plan, Upper Joshua Creek    NaN
#
#                             details
# 3534  -- bds-- ba- New construction

# %% [markdown]
# ## 🛏️ Extract Beds, Baths, sqft , Category

# %%
def extract_details(text):
    beds = re.search(r'(\d+)\s*bds?', text)
    baths = re.search(r'(\d+)\s*ba', text)
    category = re.search(r'(Townhouse|Condo|House|New construction)', text, re.IGNORECASE)
    sqft = re.search(r'([\d,]+)\s*sqft', text)
    return pd.Series({
        'beds': int(beds.group(1)) if beds else None,
        'baths': int(baths.group(1)) if baths else None,
        'category': category.group(1).title() if category else 'Unknown',
        'sqft': int(sqft.group(1).replace(',', '')) if sqft else None
    })

df[['bedrooms', 'bathrooms', 'category', 'area_sqft']] = df['details'].apply(extract_details)
df.head(20)
# Out:
#                                        address       price  \
# 0          218 Golden Trl, Vaughan, ON L6A 5A1   1199000.0
# 1           24 Sicilia St, Vaughan, ON L4H 1G3   1399999.0
# 2   81 Mahogany Forest Dr, Vaughan, ON L6A 0T1   1258800.0
# 3       99 Abner Miles Dr, Vaughan, ON L6A 4X4   2299000.0
# 4        26 Bruce St #E17, Vaughan, ON L4L 0H4    649999.0
# 5        31 Ravineview Dr, Vaughan, ON L6A 3V2    979000.0
# 6        96 Agostino Cres, Vaughan, ON L4K 5L6    999000.0
# 7      16 Via Romano Blvd, Vaughan, ON L6A 4Y9   1498900.0
# 8             18 Alba Ave, Vaughan, ON L4H 2A7   1188000.0
# 9     40 National Pine Dr, Vaughan, ON L6A 3M3    898888.0
# 10    138 Torrey Pines Rd, Vaughan, ON L4H 3X4   1488888.0
# 11       26 Moneypenny Pl, Vaughan, ON L4J 0L1   1199900.0
# 12       31 Longbridge Rd, Vaughan, ON L4J 1L7   2138000.0
# 13  235 Joseph Aaron Blvd, Vaughan, ON L4J 6C4   1399900.0
# 14            42 Tahir St, Vaughan, ON L6A 3A9    949000.0
# 15         96 Bellini Ave, Vaughan, ON L4H 0R7   1080000.0
# 16         77 Loudon Cres, Vaughan, ON L4J 8N4   1565000.0
# 17       8 Centro Park Dr, Vaughan, ON L4H 1N9    899880.0
# 18       9888 Dufferin St, Vaughan, ON L6A 1S2  10800000.0
# 19            2 Belvia Dr, Vaughan, ON L4K 5J7    998000.0
#
#                                 details  bedrooms  bathrooms   category  \
# 0         3 bds3 ba- Townhouse for sale       3.0        3.0  Townhouse
# 1             4 bds4 ba- House for sale       4.0        4.0      House
# 2             4 bds4 ba- House for sale       4.0        4.0      House
# 3             5 bds6 ba- House for sale       5.0        6.0      House
# 4             2 bds2 ba- Condo for sale       2.0        2.0      Condo
# 5             4 bds3 ba- House for sale       4.0        3.0      House
# 6             4 bds4 ba- House for sale       4.0        4.0      House
# 7         4 bds5 ba- Townhouse for sale       4.0        5.0  Townhouse
# 8             2 bds3 ba- House for sale       2.0        3.0      House
# 9             3 bds4 ba- House for sale       3.0        4.0      House
# 10            4 bds4 ba- House for sale       4.0        4.0      House
# 11        3 bds3 ba- Townhouse for sale       3.0        3.0  Townhouse
# 12            4 bds3 ba- House for sale       4.0        3.0      House
# 13            7 bds7 ba- House for sale       7.0        7.0      House
# 14            6 bds4 ba- House for sale       6.0        4.0      House
# 15            3 bds3 ba- House for sale       3.0        3.0      House
# 16            4 bds5 ba- House for sale       4.0        5.0      House
# 17            3 bds3 ba- House for sale       3.0        3.0      House
# 18            4 bds3 ba- House for sale       4.0        3.0      House
# 19  4 bds4 ba1,935 sqft- House for sale       4.0        4.0      House
#
#     area_sqft
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# 5         NaN
# 6         NaN
# 7         NaN
# 8         NaN
# 9         NaN
# 10        NaN
# 11        NaN
# 12        NaN
# 13        NaN
# 14        NaN
# 15        NaN
# 16        NaN
# 17        NaN
# 18        NaN
# 19     1935.0

# %% [markdown]
# ## 🏙️ Extract City from Address

# %%
def get_city(address):
    parts = address.split(',')
    if len(parts) >= 2:
        return parts[1].strip()
    return None

df['city'] = df['address'].apply(get_city)
df.head(10)
# Out:
#                                       address      price  \
# 0         218 Golden Trl, Vaughan, ON L6A 5A1  1199000.0
# 1          24 Sicilia St, Vaughan, ON L4H 1G3  1399999.0
# 2  81 Mahogany Forest Dr, Vaughan, ON L6A 0T1  1258800.0
# 3      99 Abner Miles Dr, Vaughan, ON L6A 4X4  2299000.0
# 4       26 Bruce St #E17, Vaughan, ON L4L 0H4   649999.0
# 5       31 Ravineview Dr, Vaughan, ON L6A 3V2   979000.0
# 6       96 Agostino Cres, Vaughan, ON L4K 5L6   999000.0
# 7     16 Via Romano Blvd, Vaughan, ON L6A 4Y9  1498900.0
# 8            18 Alba Ave, Vaughan, ON L4H 2A7  1188000.0
# 9    40 National Pine Dr, Vaughan, ON L6A 3M3   898888.0
#
#                          details  bedrooms  bathrooms   category  area_sqft  \
# 0  3 bds3 ba- Townhouse for sale       3.0        3.0  Townhouse        NaN
# 1      4 bds4 ba- House for sale       4.0        4.0      House        NaN
# 2      4 bds4 ba- House for sale       4.0        4.0      House        NaN
# 3      5 bds6 ba- House for sale       5.0        6.0      House        NaN
# 4      2 bds2 ba- Condo for sale       2.0        2.0      Condo        NaN
# 5      4 bds3 ba- House for sale       4.0        3.0      House        NaN
# 6      4 bds4 ba- House for sale       4.0        4.0      House        NaN
# 7  4 bds5 ba- Townhouse for sale       4.0        5.0  Townhouse        NaN
# 8      2 bds3 ba- House for sale       2.0        3.0      House        NaN
# 9      3 bds4 ba- House for sale       3.0        4.0      House        NaN
#
#       city
# 0  Vaughan
# 1  Vaughan
# 2  Vaughan
# 3  Vaughan
# 4  Vaughan
# 5  Vaughan
# 6  Vaughan
# 7  Vaughan
# 8  Vaughan
# 9  Vaughan

# %%
df['area_sqft'].isnull().mean()
# Out:
# np.float64(0.8726946721311475)

# %%
df.head(10)
# Out:
#                                       address      price  \
# 0         218 Golden Trl, Vaughan, ON L6A 5A1  1199000.0
# 1          24 Sicilia St, Vaughan, ON L4H 1G3  1399999.0
# 2  81 Mahogany Forest Dr, Vaughan, ON L6A 0T1  1258800.0
# 3      99 Abner Miles Dr, Vaughan, ON L6A 4X4  2299000.0
# 4       26 Bruce St #E17, Vaughan, ON L4L 0H4   649999.0
# 5       31 Ravineview Dr, Vaughan, ON L6A 3V2   979000.0
# 6       96 Agostino Cres, Vaughan, ON L4K 5L6   999000.0
# 7     16 Via Romano Blvd, Vaughan, ON L6A 4Y9  1498900.0
# 8            18 Alba Ave, Vaughan, ON L4H 2A7  1188000.0
# 9    40 National Pine Dr, Vaughan, ON L6A 3M3   898888.0
#
#                          details  bedrooms  bathrooms   category     city
# 0  3 bds3 ba- Townhouse for sale       3.0        3.0  Townhouse  Vaughan
# 1      4 bds4 ba- House for sale       4.0        4.0      House  Vaughan
# 2      4 bds4 ba- House for sale       4.0        4.0      House  Vaughan
# 3      5 bds6 ba- House for sale       5.0        6.0      House  Vaughan
# 4      2 bds2 ba- Condo for sale       2.0        2.0      Condo  Vaughan
# 5      4 bds3 ba- House for sale       4.0        3.0      House  Vaughan
# 6      4 bds4 ba- House for sale       4.0        4.0      House  Vaughan
# 7  4 bds5 ba- Townhouse for sale       4.0        5.0  Townhouse  Vaughan
# 8      2 bds3 ba- House for sale       2.0        3.0      House  Vaughan
# 9      3 bds4 ba- House for sale       3.0        4.0      House  Vaughan

# %%
# Save the updated dataset
df.to_csv("../data/processed/toronto_cleaned_housingdata.csv", index=False)

print("✅ Saved cleaned data without area_sqft.")
# Out:
# ✅ Saved cleaned data without area_sqft.
